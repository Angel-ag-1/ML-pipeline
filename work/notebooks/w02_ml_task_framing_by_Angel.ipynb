# %% [markdown]
# <a href="https://colab.research.google.com/github/Angel-ag-1/ML-pipeline/blob/main/work/notebooks/w02_ml_task_framing_by_Angel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import sys
import subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/Angel-ag-1/ML-pipeline.git"
REPO_DIR = "ML-pipeline"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

import pandas as pd
import numpy as np

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (
    df["trend_direction"]
      .str.lower()
      .eq("down")
      .astype(int)
)

print(df.shape[0], "pages | declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages | declining rate: 0.542

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# # This project is a classification task. It uses old SEO data to classify webpages based on their trend direction. The results can then help content teams decide which pages should be prioritised first for review.

# %%
# This cell is for CODE (numbers, a query, a check).

df["trend_direction"].value_counts()
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# # The target is whether a webpage is declining. I create a label called is_declining_label, where webpages with a direction treand of "down" are labelled as 1 and all other webpages are labelled as 0. This label comes from old data.

# %%
# This cell is for CODE (numbers, a query, a check).
df["is_declining_label"].value_counts()

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# is_declining_label
# 1    16262
# 0    13738
# Name: count, dtype: int64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# #The main success metric will be Precision@50. This measures how many of the top 50 webpages recommended by the model are actually declining. A higher Precision@50 means the model is better at prioritising webpages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
print("Declining pages:", df["is_declining_label"].sum())
print("Total pages:", len(df))

# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Declining pages: 16262
# Total pages: 30000

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
# # Each row in the dataset represents one webpage. Each webpage contains old SEO measurements such as impressions, CTR, engagement rate, average position and trend direction.

# %%
# This cell is for CODE (numbers, a query, a check).
df[[
    "content_age_days",
    "impressions_90d",
    "ctr",
    "engagement_rate",
    "trend_direction"
]].head()
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
#    content_age_days  impressions_90d   ctr  engagement_rate trend_direction
# 0               187             3803  0.76             5.88            down
# 1               445            15320  0.05             0.00            down
# 2               141            12581  0.09             0.00            down
# 3               463            11751  0.49             1.28          stable
# 4               263            19140  0.13             0.00            down

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# # A fixed rule may only look at one or two metrics, such as CTR or impressions. Webpage performance depends on several SEO metrics working together. A machine learning model can learn these patterns from historical data and provide better decision support for prioritising webpages for manual review.

# %%
# This cell is for CODE (numbers, a query, a check).
df[[
    "impressions_90d",
    "ctr",
    "engagement_rate",
    "avg_position"
]].describe()
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
#        impressions_90d           ctr  engagement_rate  avg_position
# count     30000.000000  30000.000000     30000.000000   30000.00000
# mean       5200.366300      0.510733         2.534520      16.34238
# std       16838.019547      3.279162         8.310096      15.21679
# min           1.000000      0.000000         0.000000       0.00000
# 25%          81.000000      0.000000         0.000000       6.20000
# 50%         731.000000      0.070000         0.000000      10.80000
# 75%        3615.250000      0.290000         1.350000      22.30000
# max      517715.000000    100.000000       100.000000     245.00000
